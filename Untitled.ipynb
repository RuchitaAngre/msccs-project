# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
data = pd.read_csv(r"C:\Users\RUCHITA ANGRE\Desktop\Project msc cs 2\project data.csv")

# %%
data
# Out:
#                            Timestamp Have you ever shopped Online?  \
# 0     2021/02/16 6:58:46 pm GMT+5:30                           Yes
# 1     2021/02/16 6:59:24 pm GMT+5:30                           Yes
# 2     2021/02/16 7:00:12 pm GMT+5:30                           Yes
# 3     2021/02/16 7:03:40 pm GMT+5:30                           Yes
# 4     2021/02/16 7:19:36 pm GMT+5:30                           Yes
# ..                               ...                           ...
# 365  2021/03/16 10:55:40 am GMT+5:30                           Yes
# 366   2021/03/16 5:15:57 pm GMT+5:30                           Yes
# 367   2021/03/16 8:51:02 pm GMT+5:30                           Yes
# 368   2021/03/16 9:25:47 pm GMT+5:30                           Yes
# 369  2021/03/17 11:26:44 pm GMT+5:30                           Yes
#
#     If Yes, Do you find Online Grocery Shopping Easier ?  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                  Yes
# 3                                                  Yes
# 4                                                  Yes
# ..                                                 ...
# 365                                                 No
# 366                                                Yes
# 367                                                Yes
# 368                                                 No
# 369                                                Yes
#
#                         Why do you  Shop Online?    \
# 0                                     All of above
# 1                               Variety of Product
# 2                                     All of above
# 3                                     All of above
# 4                               Variety of Product
# ..                                             ...
# 365  Discount & Offers;Convenient;Shop at any time
# 366                                   All of above
# 367                                   All of above
# 368            Variety of Product;Shop at any time
# 369                                   All of above
#
#     Did you find good quality of product online as compare to your Retailer Shop?  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                  Yes
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 365                                                 No
# 366                                                Yes
# 367                                                Yes
# 368                                                 No
# 369                                                Yes
#
#     Do you find enough  Quantity of grocery product  online in comparison to your Retailer ?   \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                  Yes
# 3                                                  Yes
# 4                                                  Yes
# ..                                                 ...
# 365                                                 No
# 366                                                Yes
# 367                                                Yes
# 368                                                 No
# 369                                                Yes
#
#     Are online  products cheaper in price as compared to your Retailer Shop?   \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                  Yes
# 3                                                  Yes
# 4                                                  Yes
# ..                                                 ...
# 365                                                 No
# 366                                                Yes
# 367                                                Yes
# 368                                                 No
# 369                                                Yes
#
#     Did you find product online easily ,compare to  your Retailer Shop?   \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                  Yes
# 3                                                  Yes
# 4                                                  Yes
# ..                                                 ...
# 365                                                 No
# 366                                                Yes
# 367                                                Yes
# 368                                                 No
# 369                                                Yes
#
#     Do you find any difficulties in online payment ?  \
# 0                                                 No
# 1                                                 No
# 2                                                Yes
# 3                                                Yes
# 4                                                 No
# ..                                               ...
# 365                                              Yes
# 366                                               No
# 367                                               No
# 368                                              Yes
# 369                                               No
#
#     Are you satisfied with the product  you received as compared to your  Retailer Shop?   \
# 0                                                  Yes
# 1                                                   No
# 2                                                  Yes
# 3                                                  Yes
# 4                                                  Yes
# ..                                                 ...
# 365                                                 No
# 366                                                Yes
# 367                                                Yes
# 368                                                 No
# 369                                                Yes
#
#      On scale of 5 , can you rate for following factor ? [On Time Delivery]  \
# 0                                                    5
# 1                                                    1
# 2                                                    2
# 3                                                    5
# 4                                                    2
# ..                                                 ...
# 365                                                  1
# 366                                                  5
# 367                                                  4
# 368                                                  3
# 369                                                  4
#
#      On scale of 5 , can you rate for following factor ? [Trustworthy]  \
# 0                                                    5
# 1                                                    2
# 2                                                    2
# 3                                                    5
# 4                                                    2
# ..                                                 ...
# 365                                                  1
# 366                                                  5
# 367                                                  4
# 368                                                  1
# 369                                                  4
#
#      On scale of 5 , can you rate for following factor ? [No transaction issues]  \
# 0                                                    5
# 1                                                    2
# 2                                                    2
# 3                                                    5
# 4                                                    1
# ..                                                 ...
# 365                                                  1
# 366                                                  4
# 367                                                  5
# 368                                                  1
# 369                                                  5
#
#      On scale of 5 , can you rate for following factor ? [Security]  \
# 0                                                    5
# 1                                                    2
# 2                                                    2
# 3                                                    5
# 4                                                    2
# ..                                                 ...
# 365                                                  1
# 366                                                  5
# 367                                                  5
# 368                                                  1
# 369                                                  4
#
#      On scale of 5 , can you rate for following factor ? [Product  Description]  \
# 0                                                    5
# 1                                                    2
# 2                                                    2
# 3                                                    5
# 4                                                    2
# ..                                                 ...
# 365                                                  3
# 366                                                  3
# 367                                                  5
# 368                                                  1
# 369                                                  5
#
#      On scale of 5 , can you rate for following factor ? [Product Reviews]  \
# 0                                                    4
# 1                                                    2
# 2                                                    2
# 3                                                    5
# 4                                                    1
# ..                                                 ...
# 365                                                  2
# 366                                                  3
# 367                                                  4
# 368                                                  1
# 369                                                  5
#
#     Has  COVID-19   increased time you spent online  grocery Shopping    ?   \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                  Yes
# 3                                                  Yes
# 4                                                  Yes
# ..                                                 ...
# 365                                                Yes
# 366                                                Yes
# 367                                                Yes
# 368                                                Yes
# 369                                                Yes
#
#     How often do you shop online in last six month?  \
# 0                                          Everyday
# 1                                          Everyday
# 2                                          Everyday
# 3                                          Everyday
# 4                                            Weekly
# ..                                              ...
# 365                                          Weekly
# 366                                          Weekly
# 367                                          Weekly
# 368                                          Weekly
# 369                                         Monthly
#
#     Would you prefer  shopping grocery online  than shopping  from your Retailer Shop?    \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                  Yes
# 3                                                  Yes
# 4                                                  Yes
# ..                                                 ...
# 365                                                 No
# 366                                                Yes
# 367                                                Yes
# 368                                                 No
# 369                                                Yes
#
#      Overall, How would you rate your Online Grocery Shopping Experience
# 0                                                    5
# 1                                                    1
# 2                                                    5
# 3                                                    5
# 4                                                    3
# ..                                                 ...
# 365                                                  1
# 366                                                  4
# 367                                                  4
# 368                                                  1
# 369                                                  5
#
# [370 rows x 20 columns]

# %%
data.columns
# Out:
# Index(['Timestamp', 'Have you ever shopped Online?',
#        'If Yes, Do you find Online Grocery Shopping Easier ?',
#        'Why do you  Shop Online?  ',
#        'Did you find good quality of product online as compare to your Retailer Shop?',
#        'Do you find enough  Quantity of grocery product  online in comparison to your Retailer ? ',
#        'Are online  products cheaper in price as compared to your Retailer Shop? ',
#        'Did you find product online easily ,compare to  your Retailer Shop? ',
#        'Do you find any difficulties in online payment ?',
#        'Are you satisfied with the product  you received as compared to your  Retailer Shop? ',
#        'On scale of 5 , can you rate for following factor ? [On Time Delivery]',
#        'On scale of 5 , can you rate for following factor ? [Trustworthy]',
#        'On scale of 5 , can you rate for following factor ? [No transaction issues]',
#        'On scale of 5 , can you rate for following factor ? [Security]',
#        'On scale of 5 , can you rate for following factor ? [Product  Description]',
#        'On scale of 5 , can you rate for following factor ? [Product Reviews]',
#        'Has  COVID-19   increased time you spent online  grocery Shopping    ? ',
#        'How often do you shop online in last six month?',
#        'Would you prefer  shopping grocery online  than shopping  from your Retailer Shop?  ',
#        'Overall, How would you rate your Online Grocery Shopping Experience'],
#       dtype='object')

# %%
data.assign(dummy = 1).groupby(
  ['dummy','On scale of 5 , can you rate for following factor ? [On Time Delivery]',
       'On scale of 5 , can you rate for following factor ? [Trustworthy]',
       'On scale of 5 , can you rate for following factor ? [No transaction issues]',
       'On scale of 5 , can you rate for following factor ? [Security]',
       'On scale of 5 , can you rate for following factor ? [Product  Description]',
       'On scale of 5 , can you rate for following factor ? [Product Reviews]']
).size().to_frame().unstack().plot(kind='barh',stacked=True,legend=False, figsize=(30, 50))

plt.title('Number of records by State')

# other it'll show up as 'dummy' 


# disable ticks in the x axis
plt.xticks([])

# fix the legend
current_handles, _ = plt.gca().get_legend_handles_labels()
reversed_handles = reversed(current_handles)



plt.legend(reversed_handles,loc='lower right')

plt.show()

# %%
data.assign(dummy = 1).groupby(
  ['dummy','On scale of 5 , can you rate for following factor ? [On Time Delivery]',
       'On scale of 5 , can you rate for following factor ? [Trustworthy]',
       'On scale of 5 , can you rate for following factor ? [No transaction issues]',
       'On scale of 5 , can you rate for following factor ? [Security]',
       'On scale of 5 , can you rate for following factor ? [Product  Description]',
       'On scale of 5 , can you rate for following factor ? [Product Reviews]']
).size().to_frame().unstack().plot(kind='line',stacked=True,legend=False, figsize=(20, 10))

plt.title("Rating Scale")

# other it'll show up as 'dummy' 


# disable ticks in the x axis
plt.xticks([])

# fix the legend
current_handles, _ = plt.gca().get_legend_handles_labels()
reversed_handles = reversed(current_handles)


plt.ylim(0, 20)
plt.legend(reversed_handles,labels,loc='lower right')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-0033f9f9231b> in <module>
#      22
#      23 plt.ylim(0, 20)
# ---> 24 plt.legend(reversed_handles,labels,loc='lower right')
#      25
#      26 plt.show()
#
# NameError: name 'labels' is not defined

# %%
data.assign(dummy = 1).groupby(
  ['dummy','On scale of 5 , can you rate for following factor ? [On Time Delivery]',
       'On scale of 5 , can you rate for following factor ? [Trustworthy]',
       'On scale of 5 , can you rate for following factor ? [No transaction issues]',
       'On scale of 5 , can you rate for following factor ? [Security]',
       'On scale of 5 , can you rate for following factor ? [Product  Description]',
       'On scale of 5 , can you rate for following factor ? [Product Reviews]']
).size().to_frame().unstack().plot(kind='hist',stacked=True,legend=False, figsize=(20, 10))

plt.title("Rating Scale")

# other it'll show up as 'dummy' 


# disable ticks in the x axis
plt.xticks([])

# fix the legend
current_handles, _ = plt.gca().get_legend_handles_labels()
reversed_handles = reversed(current_handles)


plt.ylim(0, 20)
plt.legend(reversed_handles,labels,loc='lower right')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-43ffee0542c7> in <module>
#      22
#      23 plt.ylim(0, 20)
# ---> 24 plt.legend(reversed_handles,labels,loc='lower right')
#      25
#      26 plt.show()
#
# NameError: name 'labels' is not defined

# %%
data.assign(dummy = 1).groupby(
  ['dummy','On scale of 5 , can you rate for following factor ? [On Time Delivery]',
       'On scale of 5 , can you rate for following factor ? [Trustworthy]',
       'On scale of 5 , can you rate for following factor ? [No transaction issues]',
       'On scale of 5 , can you rate for following factor ? [Security]',
       'On scale of 5 , can you rate for following factor ? [Product  Description]',
       'On scale of 5 , can you rate for following factor ? [Product Reviews]']
).size().to_frame().unstack().plot(kind='box',stacked=True,legend=False, figsize=(20, 10))

plt.title("Rating Scale")

# other it'll show up as 'dummy' 


# disable ticks in the x axis
plt.xticks([])

# fix the legend
current_handles, _ = plt.gca().get_legend_handles_labels()
reversed_handles = reversed(current_handles)


plt.ylim(0, 20)
plt.legend(reversed_handles,loc='lower right')

plt.show()
